# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.3'

# %% [markdown]
# # DataFrame

# %%
dataset = {
    'Name':["sumon","galib","junaed","kamrul"],
    'passing year': ["2023","2024","2022","2023"]
    
}

# %%
var1 = pd.DataFrame(dataset)

# %%
print(var1)
# Out:
#      Name passing year
# 0   sumon         2023
# 1   galib         2024
# 2  junaed         2022
# 3  kamrul         2023

# %% [markdown]
# # Series

# %%
var2 = ["sumon","galib","nerob","kamrul"]

# %%
pd.Series(var2)
# Out:
# 0     sumon
# 1     galib
# 2     nerob
# 3    kamrul
# dtype: object

# %%
pd.Series(var2,index=["w","x","y","z"])
# Out:
# w     sumon
# x     galib
# y     nerob
# z    kamrul
# dtype: object

# %%
var3 = {"sumon":2023,"kamrul":2023,"galib":2024}

# %%
pd.Series(var3)
# Out:
# sumon     2023
# kamrul    2023
# galib     2024
# dtype: int64

# %% [markdown]
# # DataFrame to csv

# %%
dataset = {
    'Name':["sumon","galib","junaed","kamrul"],
    'passing year': ["2023","2024","2022","2023"],
    'Institute': ["MIST","RUET","AIUB","MIST"]
    
}

# %%
df = pd.DataFrame(dataset)
df.to_csv("data1.csv",index=False)

# %%
df1 = pd.read_csv("data1.csv")

# %%
df1.head()
# Out:
#      Name  passing year Institute
# 0   sumon          2023      MIST
# 1   galib          2024      RUET
# 2  junaed          2022      AIUB
# 3  kamrul          2023      MIST

# %%
df1.tail()
# Out:
#      Name  passing year Institute
# 0   sumon          2023      MIST
# 1   galib          2024      RUET
# 2  junaed          2022      AIUB
# 3  kamrul          2023      MIST

# %%
df1.describe()
# Out:
#        passing year
# count      4.000000
# mean    2023.000000
# std        0.816497
# min     2022.000000
# 25%     2022.750000
# 50%     2023.000000
# 75%     2023.250000
# max     2024.000000

# %%
df1
# Out:
#      Name  passing year Institute
# 0   sumon          2023      MIST
# 1   galib          2024      RUET
# 2  junaed          2022      AIUB
# 3  kamrul          2023      MIST

# %%
# DataFrame - multiple row/column
# Series - Signle row/column

# %%
import numpy as np #pip install numpy

# %%
series = pd.Series(np.random.rand(10))

# %%
series
# Out:
# 0    0.700151
# 1    0.791421
# 2    0.901353
# 3    0.795184
# 4    0.652031
# 5    0.028364
# 6    0.198028
# 7    0.257387
# 8    0.860049
# 9    0.838726
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
DataNew = pd.DataFrame(np.random.rand(100,5),index=np.arange(100))

# %%
DataNew.head()
# Out:
#           0         1         2         3         4
# 0  0.599884  0.832771  0.895870  0.953039  0.657813
# 1  0.104525  0.507601  0.240963  0.032275  0.876645
# 2  0.498608  0.302073  0.389966  0.202844  0.238372
# 3  0.680715  0.110231  0.962509  0.781058  0.750152
# 4  0.695632  0.217096  0.214187  0.111732  0.505393

# %%
DataNew.describe()
# Out:
#                 0           1           2           3           4
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.424153    0.513374    0.507364    0.498750    0.519100
# std      0.286733    0.290676    0.310650    0.303952    0.269930
# min      0.013340    0.004952    0.015831    0.024472    0.024800
# 25%      0.152486    0.298536    0.230350    0.247747    0.307153
# 50%      0.415101    0.518177    0.494836    0.510668    0.489883
# 75%      0.696370    0.775125    0.777995    0.777133    0.737414
# max      0.940763    0.994005    0.997416    0.997980    0.995613

# %%
type(DataNew)
# Out:
# pandas.core.frame.DataFrame

# %%
DataNew.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
DataNew[2][4]
# Out:
# 0.21418702143997914

# %%
DataNew[2][4] = 1

# %%
DataNew.head()
# Out:
#           0         1         2         3         4
# 0  0.599884  0.832771  0.895870  0.953039  0.657813
# 1  0.104525  0.507601  0.240963  0.032275  0.876645
# 2  0.498608  0.302073  0.389966  0.202844  0.238372
# 3  0.680715  0.110231  0.962509  0.781058  0.750152
# 4  0.695632  0.217096  1.000000  0.111732  0.505393

# %%
DataNew.to_numpy()
# Out:
# array([[0.59988436, 0.83277088, 0.89587017, 0.95303926, 0.65781291],
#        [0.10452547, 0.50760122, 0.24096321, 0.03227538, 0.87664487],
#        [0.49860828, 0.302073  , 0.38996574, 0.20284389, 0.2383722 ],
#        [0.68071507, 0.11023059, 0.96250915, 0.78105845, 0.75015237],
#        [0.69563154, 0.21709631, 1.        , 0.11173249, 0.50539266],
#        [0.5551517 , 0.67604523, 0.01583078, 0.64072914, 0.70153249],
#        [0.83650145, 0.55576313, 0.89634002, 0.47714566, 0.43591914],
#        [0.05482259, 0.39095081, 0.76790221, 0.41901207, 0.63475031],
#        [0.03910165, 0.77352769, 0.98579504, 0.25976738, 0.96871513],
#        [0.15181916, 0.62803479, 0.57288534, 0.39964453, 0.63878798],
#        [0.64080959, 0.16485678, 0.25134068, 0.95509492, 0.52822372],
#        [0.26698211, 0.55182349, 0.75758952, 0.32489021, 0.82025166],
#        [0.70249646, 0.60972367, 0.43120022, 0.25829053, 0.6712765 ],
#        [0.12719602, 0.33987692, 0.29447939, 0.05850773, 0.25576521],
# ...

# %%
type(DataNew)
# Out:
# pandas.core.frame.DataFrame

# %%
DataNew.T
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.599884  0.104525  0.498608  0.680715  0.695632  0.555152  0.836501
# 1  0.832771  0.507601  0.302073  0.110231  0.217096  0.676045  0.555763
# 2  0.895870  0.240963  0.389966  0.962509  1.000000  0.015831  0.896340
# 3  0.953039  0.032275  0.202844  0.781058  0.111732  0.640729  0.477146
# 4  0.657813  0.876645  0.238372  0.750152  0.505393  0.701532  0.435919
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.054823  0.039102  0.151819  ...  0.467748  0.542238  0.420641  0.041490
# 1  0.390951  0.773528  0.628035  ...  0.555880  0.419760  0.478323  0.473140
# 2  0.767902  0.985795  0.572885  ...  0.099988  0.309094  0.990890  0.226265
# 3  0.419012  0.259767  0.399645  ...  0.609681  0.468047  0.251260  0.817154
# 4  0.634750  0.968715  0.638788  ...  0.578682  0.861638  0.134563  0.438833
#
#          94        95        96        97        98        99
# ...

# %%
DataNew.sort_index(axis=1,ascending=False)
# Out:
#            4         3         2         1         0
# 0   0.657813  0.953039  0.895870  0.832771  0.599884
# 1   0.876645  0.032275  0.240963  0.507601  0.104525
# 2   0.238372  0.202844  0.389966  0.302073  0.498608
# 3   0.750152  0.781058  0.962509  0.110231  0.680715
# 4   0.505393  0.111732  1.000000  0.217096  0.695632
# ..       ...       ...       ...       ...       ...
# 95  0.918832  0.497836  0.815489  0.004952  0.018402
# 96  0.503590  0.948118  0.790699  0.547309  0.207811
# 97  0.395195  0.532570  0.272897  0.380163  0.775627
# 98  0.400420  0.548347  0.437505  0.648278  0.909770
# 99  0.576225  0.853255  0.655840  0.238122  0.394131
#
# [100 rows x 5 columns]

# %%
DataNew2 = DataNew

# %%
DataNew2
# Out:
#            0         1         2         3         4
# 0   0.599884  0.832771  0.895870  0.953039  0.657813
# 1   0.104525  0.507601  0.240963  0.032275  0.876645
# 2   0.498608  0.302073  0.389966  0.202844  0.238372
# 3   0.680715  0.110231  0.962509  0.781058  0.750152
# 4   0.695632  0.217096  1.000000  0.111732  0.505393
# ..       ...       ...       ...       ...       ...
# 95  0.018402  0.004952  0.815489  0.497836  0.918832
# 96  0.207811  0.547309  0.790699  0.948118  0.503590
# 97  0.775627  0.380163  0.272897  0.532570  0.395195
# 98  0.909770  0.648278  0.437505  0.548347  0.400420
# 99  0.394131  0.238122  0.655840  0.853255  0.576225
#
# [100 rows x 5 columns]

# %%
DataNew2[2][0] = "sumon"

# %%
DataNew
# Out:
#            0         1         2         3         4
# 0   0.599884  0.832771     sumon  0.953039  0.657813
# 1   0.104525  0.507601  0.240963  0.032275  0.876645
# 2   0.498608  0.302073  0.389966  0.202844  0.238372
# 3   0.680715  0.110231  0.962509  0.781058  0.750152
# 4   0.695632  0.217096       1.0  0.111732  0.505393
# ..       ...       ...       ...       ...       ...
# 95  0.018402  0.004952  0.815489  0.497836  0.918832
# 96  0.207811  0.547309  0.790699  0.948118  0.503590
# 97  0.775627  0.380163  0.272897  0.532570  0.395195
# 98  0.909770  0.648278  0.437505  0.548347  0.400420
# 99  0.394131  0.238122   0.65584  0.853255  0.576225
#
# [100 rows x 5 columns]

# %%
DataNew2 = DataNew.copy()

# %%
DataNew2[3][0] = "galib"
# Out:
# C:\Users\UseR\AppData\Local\Temp\ipykernel_22192\2758074586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DataNew2[3][0] = "galib"

# %%
DataNew
# Out:
#            0         1         2         3         4
# 0   0.599884  0.832771     sumon  0.953039  0.657813
# 1   0.104525  0.507601  0.240963  0.032275  0.876645
# 2   0.498608  0.302073  0.389966  0.202844  0.238372
# 3   0.680715  0.110231  0.962509  0.781058  0.750152
# 4   0.695632  0.217096       1.0  0.111732  0.505393
# ..       ...       ...       ...       ...       ...
# 95  0.018402  0.004952  0.815489  0.497836  0.918832
# 96  0.207811  0.547309  0.790699  0.948118  0.503590
# 97  0.775627  0.380163  0.272897  0.532570  0.395195
# 98  0.909770  0.648278  0.437505  0.548347  0.400420
# 99  0.394131  0.238122   0.65584  0.853255  0.576225
#
# [100 rows x 5 columns]

# %%
DataNew2
# Out:
#            0         1         2         3         4
# 0   0.599884  0.832771     sumon     galib  0.657813
# 1   0.104525  0.507601  0.240963  0.032275  0.876645
# 2   0.498608  0.302073  0.389966  0.202844  0.238372
# 3   0.680715  0.110231  0.962509  0.781058  0.750152
# 4   0.695632  0.217096       1.0  0.111732  0.505393
# ..       ...       ...       ...       ...       ...
# 95  0.018402  0.004952  0.815489  0.497836  0.918832
# 96  0.207811  0.547309  0.790699  0.948118  0.503590
# 97  0.775627  0.380163  0.272897   0.53257  0.395195
# 98  0.909770  0.648278  0.437505  0.548347  0.400420
# 99  0.394131  0.238122   0.65584  0.853255  0.576225
#
# [100 rows x 5 columns]

# %%
DataNew4 = DataNew

# %%
DataNew3.head(3)
# Out:
#             0           1         2         3         4
# 0  678.000000    0.832771     sumon  0.953039  0.657813
# 1  678.000000  678.000000  0.240963  0.032275  0.876645
# 2    0.498608    0.302073  0.389966  0.202844  0.238372

# %%
DataNew3[1][1] = 678
# Out:
# C:\Users\UseR\AppData\Local\Temp\ipykernel_22192\570896508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DataNew3[1][1] = 678

# %%
DataNew3
# Out:
#              0           1         2         3         4
# 0   678.000000    0.832771     sumon  0.953039  0.657813
# 1   678.000000  678.000000  0.240963  0.032275  0.876645
# 2     0.498608    0.302073  0.389966  0.202844  0.238372
# 3     0.680715    0.110231  0.962509  0.781058  0.750152
# 4     0.695632    0.217096       1.0  0.111732  0.505393
# ..         ...         ...       ...       ...       ...
# 95    0.018402    0.004952  0.815489  0.497836  0.918832
# 96    0.207811    0.547309  0.790699  0.948118  0.503590
# 97    0.775627    0.380163  0.272897  0.532570  0.395195
# 98    0.909770    0.648278  0.437505  0.548347  0.400420
# 99    0.394131    0.238122   0.65584  0.853255  0.576225
#
# [100 rows x 5 columns]

# %%
DataNew3.loc[0,2] = 789

# %%
DataNew3
# Out:
#              0           1         2         3         4
# 0   778.000000    0.832771       789  0.953039  0.657813
# 1   678.000000  678.000000  0.240963  0.032275  0.876645
# 2     0.498608    0.302073  0.389966  0.202844  0.238372
# 3     0.680715    0.110231  0.962509  0.781058  0.750152
# 4     0.695632    0.217096       1.0  0.111732  0.505393
# ..         ...         ...       ...       ...       ...
# 95    0.018402    0.004952  0.815489  0.497836  0.918832
# 96    0.207811    0.547309  0.790699  0.948118  0.503590
# 97    0.775627    0.380163  0.272897  0.532570  0.395195
# 98    0.909770    0.648278  0.437505  0.548347  0.400420
# 99    0.394131    0.238122   0.65584  0.853255  0.576225
#
# [100 rows x 5 columns]

# %%
DataNew3.head(3)
# Out:
#             0           1         2         3         4
# 0  778.000000    0.832771       789  0.953039  0.657813
# 1  678.000000  678.000000  0.240963  0.032275  0.876645
# 2    0.498608    0.302073  0.389966  0.202844  0.238372

# %%
DataNew3.columns = list("wxyzp")

# %%
DataNew3.head(3)
# Out:
#             w           x         y         z         p
# 0  778.000000    0.832771       789  0.953039  0.657813
# 1  678.000000  678.000000  0.240963  0.032275  0.876645
# 2    0.498608    0.302073  0.389966  0.202844  0.238372

# %%
DataNew3.loc[0,'y'] = 790

# %%
DataNew3
# Out:
#              w           x         y         z         p      2
# 0   778.000000    0.832771       790  0.953039  0.657813  789.0
# 1   678.000000  678.000000  0.240963  0.032275  0.876645    NaN
# 2     0.498608    0.302073  0.389966  0.202844  0.238372    NaN
# 3     0.680715    0.110231  0.962509  0.781058  0.750152    NaN
# 4     0.695632    0.217096       1.0  0.111732  0.505393    NaN
# ..         ...         ...       ...       ...       ...    ...
# 95    0.018402    0.004952  0.815489  0.497836  0.918832    NaN
# 96    0.207811    0.547309  0.790699  0.948118  0.503590    NaN
# 97    0.775627    0.380163  0.272897  0.532570  0.395195    NaN
# 98    0.909770    0.648278  0.437505  0.548347  0.400420    NaN
# 99    0.394131    0.238122   0.65584  0.853255  0.576225    NaN
#
# [100 rows x 6 columns]

# %%
DataNew3.drop(2,axis=1,inplace=True)

# %%
DataNew3.loc[[4,5],:]
# Out:
#           w         x         y         z         p
# 4  0.695632  0.217096       1.0  0.111732  0.505393
# 5  0.555152  0.676045  0.015831  0.640729  0.701532

# %%
DataNew3.loc[(DataNew3['y']>0.5) & (DataNew3['w'])>0]
# Out:
#              w         x         y         z         p
# 0   778.000000  0.832771       790  0.953039  0.657813
# 3     0.680715  0.110231  0.962509  0.781058  0.750152
# 4     0.695632  0.217096       1.0  0.111732  0.505393
# 6     0.836501  0.555763   0.89634  0.477146  0.435919
# 7     0.054823  0.390951  0.767902  0.419012  0.634750
# 8     0.039102  0.773528  0.985795  0.259767  0.968715
# 9     0.151819  0.628035  0.572885  0.399645  0.638788
# 11    0.266982  0.551823   0.75759  0.324890  0.820252
# 14    0.409562  0.902969  0.846305  0.919488  0.358623
# 15    0.311195  0.160197   0.85808  0.775825  0.251105
# 21    0.774598  0.392692  0.903029  0.967616  0.260560
# 22    0.303488  0.017259  0.997416  0.875423  0.272340
# 27    0.558532  0.587845  0.554203  0.040765  0.040944
# 30    0.794195  0.385932  0.635173  0.708434  0.732283
# 32    0.596992  0.032841  0.537932  0.258952  0.863074
# 35    0.188592  0.306661  0.813578  0.554060  0.621912
# ...

# %%
DataNew3.head(4)
# Out:
#             w           x         y         z         p
# 0  778.000000    0.832771       790  0.953039  0.657813
# 1  678.000000  678.000000  0.240963  0.032275  0.876645
# 2    0.498608    0.302073  0.389966  0.202844  0.238372
# 3    0.680715    0.110231  0.962509  0.781058  0.750152

# %%
DataNew3.iloc[0,2] = 890

# %%
DataNew3.head(3)
# Out:
#             w           x         y         z         p
# 0  778.000000    0.832771       890  0.953039  0.657813
# 1  678.000000  678.000000  0.240963  0.032275  0.876645
# 2    0.498608    0.302073  0.389966  0.202844  0.238372

# %%
DataNew3.iloc[[0,1],[1,2]]
# Out:
#             x         y
# 0    0.832771       890
# 1  678.000000  0.240963
